# %%
import os
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import models
from IPython import display

# Set the seed value for experiment reproducibility.
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
DATASET_PATH = 'test2_wszystkie'

data_dir = pathlib.Path(DATASET_PATH)

# %%
commands = np.array(tf.io.gfile.listdir(str(data_dir)))
commands = commands[commands != 'README.md']
print('Commands:', commands)
# Out:
# Commands: ['1_szafa' '2_szopa' '3_szelki' '4_kasza' '5_nosze' '6_wieszak' '7_kosz'
#  '8_afisz' '9_gulasz']

# %%
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')
filenames = tf.random.shuffle(filenames)
num_samples = len(filenames)

# %%
train_files = filenames[:int(num_samples*0.8)]
val_files = filenames[int(num_samples*0.8):int(num_samples*0.9)]
test_files = filenames[int(num_samples*0.9):]

print('Training set size', len(train_files))
print('Validation set size', len(val_files))
print('Test set size', len(test_files))
# Out:
# Training set size 3600
# Validation set size 450
# Test set size 450

# %%
def decode_audio(audio_binary):
  audio, _ = tf.audio.decode_wav(contents=audio_binary)
  return tf.squeeze(audio, axis=-1)

# %%
def get_label(file_path):
  parts = tf.strings.split(
      input=file_path,
      sep=os.path.sep)
  return parts[-2]

# %%
def get_waveform_and_label(file_path):
  label = get_label(file_path)
  audio_binary = tf.io.read_file(file_path)
  waveform = decode_audio(audio_binary)
  return waveform, label

# %%
AUTOTUNE = tf.data.AUTOTUNE

files_ds = tf.data.Dataset.from_tensor_slices(train_files)

waveform_ds = files_ds.map(
    map_func=get_waveform_and_label,
    num_parallel_calls=AUTOTUNE)

# %%
rows = 3
cols = 3
n = rows * cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 12))

for i, (audio, label) in enumerate(waveform_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  ax.plot(audio.numpy())
  ax.set_yticks(np.arange(-1.2, 1.2, 0.2))
  label = label.numpy().decode('utf-8')
  ax.set_title(label)

plt.show()

# %%
def get_spectrogram(waveform):
  input_len = 16000
  waveform = waveform[:input_len]
  zero_padding = tf.zeros(
      [16000] - tf.shape(waveform),
      dtype=tf.float32)
  waveform = tf.cast(waveform, dtype=tf.float32)
  equal_length = tf.concat([waveform, zero_padding], 0)
  spectrogram = tf.signal.stft(
      equal_length, frame_length=255, frame_step=128)
  spectrogram = tf.abs(spectrogram)
  spectrogram = spectrogram[..., tf.newaxis]
  return spectrogram

# %%
for waveform, label in waveform_ds.take(1):
  label = label.numpy().decode('utf-8')
  spectrogram = get_spectrogram(waveform)

print('Label:', label)
print('Waveform shape:', waveform.shape)
print('Spectrogram shape:', spectrogram.shape)
print('Audio playback')


display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: 3_szelki
# Waveform shape: (38014,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure()
plt.imshow(tf.squeeze(spectrogram, axis=-1).numpy())
plt.title('Spectrogram')
plt.show()

# %%
def plot_spectrogram(spectrogram, ax):
  if len(spectrogram.shape) > 2:
    assert len(spectrogram.shape) == 3
    spectrogram = np.squeeze(spectrogram, axis=-1)
  log_spec = np.log(spectrogram.T + np.finfo(float).eps)
  height = log_spec.shape[0]
  width = log_spec.shape[1]
  X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
  Y = range(height)
  ax.pcolormesh(X, Y, log_spec)

# %%
fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 16000])

plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.show()

# %%
def get_spectrogram_and_label_id(audio, label):
  spectrogram = get_spectrogram(audio)
  label_id = tf.argmax(label == commands)
  return spectrogram, label_id

# %%
spectrogram_ds = waveform_ds.map(
  map_func=get_spectrogram_and_label_id,
  num_parallel_calls=AUTOTUNE)

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 10))

for i, (spectrogram, label_id) in enumerate(spectrogram_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  plot_spectrogram(spectrogram.numpy(), ax)
  ax.set_title(commands[label_id.numpy()])
  ax.axis('off')
  
plt.show()

# %%
def preprocess_dataset(files):
  files_ds = tf.data.Dataset.from_tensor_slices(files)
  output_ds = files_ds.map(
      map_func=get_waveform_and_label,
      num_parallel_calls=AUTOTUNE)
  output_ds = output_ds.map(
      map_func=get_spectrogram_and_label_id,
      num_parallel_calls=AUTOTUNE)
  return output_ds

# %%
train_ds = spectrogram_ds
val_ds = preprocess_dataset(val_files)
test_ds = preprocess_dataset(test_files)

# %%
batch_size = 64
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %%
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
for spectrogram, _ in spectrogram_ds.take(1):
  input_shape = spectrogram.shape
print('Input shape:', input_shape)
num_labels = len(commands)

norm_layer = layers.Normalization()
norm_layer.adapt(data=spectrogram_ds.map(map_func=lambda spec, label: spec))

model = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Resizing(32, 32),
    norm_layer,
    layers.Conv2D(32, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(64, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),
    layers.Conv2D(128, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Conv2D(256, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])


model.summary()
# Out:
# Input shape: (124, 129, 1)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resizing (Resizing)             │ (None, 32, 32, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalization (Normalization)   │ (None, 32, 32, 1)      │             3 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 30, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 28, 28, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 9)              │         2,313 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 654,476 (2.50 MB)
#  Trainable params: 653,513 (2.49 MB)
#  Non-trainable params: 963 (3.77 KB)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %%
EPOCHS = 100
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - accuracy: 0.2579 - loss: 2.7104 - val_accuracy: 0.1800 - val_loss: 2.1363
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.4900 - loss: 1.3814 - val_accuracy: 0.1333 - val_loss: 3.0352
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.5791 - loss: 1.0431 - val_accuracy: 0.1467 - val_loss: 3.9434
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.6675 - loss: 0.8639 - val_accuracy: 0.1578 - val_loss: 4.2738
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.7100 - loss: 0.7204 - val_accuracy: 0.1733 - val_loss: 3.7332
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.7771 - loss: 0.5885 - val_accuracy: 0.2889 - val_loss: 2.2250
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.7830 - loss: 0.5576 - val_accuracy: 0.3378 - val_loss: 2.3121
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8242 - loss: 0.4462 - val_accuracy: 0.3400 - val_loss: 2.5267
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.8600 - loss: 0.3859 - val_accuracy: 0.5533 - val_loss: 1.5457
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8756 - loss: 0.3347 - val_accuracy: 0.4556 - val_loss: 2.8357
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9074 - loss: 0.2665 - val_accuracy: 0.7911 - val_loss: 0.6153
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.8975 - loss: 0.2962 - val_accuracy: 0.7800 - val_loss: 0.9377
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9148 - loss: 0.2498 - val_accuracy: 0.7378 - val_loss: 0.9168
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9221 - loss: 0.2099 - val_accuracy: 0.8067 - val_loss: 0.8722
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9328 - loss: 0.1848 - val_accuracy: 0.8489 - val_loss: 0.4757
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9201 - loss: 0.2210 - val_accuracy: 0.8244 - val_loss: 0.5654
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9432 - loss: 0.1704 - val_accuracy: 0.8756 - val_loss: 0.3696
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9534 - loss: 0.1273 - val_accuracy: 0.8600 - val_loss: 0.4663
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9603 - loss: 0.1182 - val_accuracy: 0.8000 - val_loss: 1.0167
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9636 - loss: 0.1190 - val_accuracy: 0.8178 - val_loss: 0.7607
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9575 - loss: 0.1222 - val_accuracy: 0.8400 - val_loss: 0.4595
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9582 - loss: 0.1343 - val_accuracy: 0.8978 - val_loss: 0.2960
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9668 - loss: 0.1014 - val_accuracy: 0.8422 - val_loss: 0.5333
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9727 - loss: 0.0807 - val_accuracy: 0.8333 - val_loss: 0.6824
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9693 - loss: 0.0864 - val_accuracy: 0.7200 - val_loss: 1.1067
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9710 - loss: 0.0874 - val_accuracy: 0.8622 - val_loss: 0.5434
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9747 - loss: 0.0804 - val_accuracy: 0.7689 - val_loss: 0.8622
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9709 - loss: 0.0919 - val_accuracy: 0.7511 - val_loss: 0.7921
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9705 - loss: 0.0786 - val_accuracy: 0.7911 - val_loss: 0.7633
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9744 - loss: 0.0857 - val_accuracy: 0.8622 - val_loss: 0.4443
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.9680 - loss: 0.0968 - val_accuracy: 0.8978 - val_loss: 0.3666
# Epoch 32/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.9762 - loss: 0.0795 - val_accuracy: 0.9089 - val_loss: 0.3618
# Epoch 33/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.9673 - loss: 0.0910 - val_accuracy: 0.7911 - val_loss: 1.0640
# Epoch 34/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9739 - loss: 0.0759 - val_accuracy: 0.8556 - val_loss: 0.6083
# Epoch 35/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9763 - loss: 0.0622 - val_accuracy: 0.9378 - val_loss: 0.2159
# Epoch 36/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9798 - loss: 0.0510 - val_accuracy: 0.9200 - val_loss: 0.4209
# Epoch 37/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9792 - loss: 0.0716 - val_accuracy: 0.9356 - val_loss: 0.2951
# Epoch 38/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9778 - loss: 0.0644 - val_accuracy: 0.9133 - val_loss: 0.3488
# Epoch 39/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9856 - loss: 0.0513 - val_accuracy: 0.7756 - val_loss: 1.3036
# Epoch 40/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9783 - loss: 0.0723 - val_accuracy: 0.9133 - val_loss: 0.3783
# Epoch 41/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9783 - loss: 0.0669 - val_accuracy: 0.8178 - val_loss: 0.9063
# Epoch 42/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9787 - loss: 0.0561 - val_accuracy: 0.8044 - val_loss: 1.1195
# Epoch 43/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9795 - loss: 0.0651 - val_accuracy: 0.7689 - val_loss: 1.0872
# Epoch 44/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9766 - loss: 0.0740 - val_accuracy: 0.8867 - val_loss: 0.4488
# Epoch 45/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9815 - loss: 0.0562 - val_accuracy: 0.9311 - val_loss: 0.2337
# Epoch 46/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9858 - loss: 0.0450 - val_accuracy: 0.8422 - val_loss: 0.9200
# Epoch 47/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9847 - loss: 0.0504 - val_accuracy: 0.8444 - val_loss: 0.7003
# Epoch 48/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9851 - loss: 0.0405 - val_accuracy: 0.9311 - val_loss: 0.3252
# Epoch 49/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9787 - loss: 0.0585 - val_accuracy: 0.8578 - val_loss: 0.5781
# Epoch 50/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9850 - loss: 0.0429 - val_accuracy: 0.8933 - val_loss: 0.6355
# Epoch 51/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9759 - loss: 0.0694 - val_accuracy: 0.9067 - val_loss: 0.3914
# Epoch 52/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9892 - loss: 0.0396 - val_accuracy: 0.8378 - val_loss: 1.1066
# Epoch 53/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.9864 - loss: 0.0340 - val_accuracy: 0.9022 - val_loss: 0.3355
# Epoch 54/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.9919 - loss: 0.0265 - val_accuracy: 0.7333 - val_loss: 3.5570
# Epoch 55/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.9831 - loss: 0.0395 - val_accuracy: 0.7422 - val_loss: 2.3665
# Epoch 56/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 108ms/step - accuracy: 0.9856 - loss: 0.0468 - val_accuracy: 0.9333 - val_loss: 0.3377
# Epoch 57/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 106ms/step - accuracy: 0.9781 - loss: 0.0671 - val_accuracy: 0.8778 - val_loss: 0.6820
# Epoch 58/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.9837 - loss: 0.0436 - val_accuracy: 0.8422 - val_loss: 0.4982
# Epoch 59/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9832 - loss: 0.0550 - val_accuracy: 0.8778 - val_loss: 0.4004
# Epoch 60/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9763 - loss: 0.0786 - val_accuracy: 0.9067 - val_loss: 0.7030
# Epoch 61/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9745 - loss: 0.0839 - val_accuracy: 0.9067 - val_loss: 0.5231
# Epoch 62/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9771 - loss: 0.0720 - val_accuracy: 0.9400 - val_loss: 0.1988
# Epoch 63/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9814 - loss: 0.0560 - val_accuracy: 0.8667 - val_loss: 0.5421
# Epoch 64/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9860 - loss: 0.0523 - val_accuracy: 0.9089 - val_loss: 0.4312
# Epoch 65/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9854 - loss: 0.0468 - val_accuracy: 0.7178 - val_loss: 1.2295
# Epoch 66/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9881 - loss: 0.0315 - val_accuracy: 0.9578 - val_loss: 0.1981
# Epoch 67/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9881 - loss: 0.0378 - val_accuracy: 0.9400 - val_loss: 0.1947
# Epoch 68/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9859 - loss: 0.0474 - val_accuracy: 0.9467 - val_loss: 0.2839
# Epoch 69/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9903 - loss: 0.0249 - val_accuracy: 0.8044 - val_loss: 1.6961
# Epoch 70/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9889 - loss: 0.0287 - val_accuracy: 0.9467 - val_loss: 0.1799
# Epoch 71/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9857 - loss: 0.0464 - val_accuracy: 0.8711 - val_loss: 0.4304
# Epoch 72/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9875 - loss: 0.0365 - val_accuracy: 0.8756 - val_loss: 0.5171
# Epoch 73/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9899 - loss: 0.0327 - val_accuracy: 0.9133 - val_loss: 0.4555
# Epoch 74/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9904 - loss: 0.0248 - val_accuracy: 0.7733 - val_loss: 2.0411
# Epoch 75/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9865 - loss: 0.0308 - val_accuracy: 0.9000 - val_loss: 0.3593
# Epoch 76/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9887 - loss: 0.0352 - val_accuracy: 0.9333 - val_loss: 0.3940
# Epoch 77/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9867 - loss: 0.0437 - val_accuracy: 0.8556 - val_loss: 0.5150
# Epoch 78/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9868 - loss: 0.0422 - val_accuracy: 0.6378 - val_loss: 2.0067
# Epoch 79/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9873 - loss: 0.0379 - val_accuracy: 0.9178 - val_loss: 0.2431
# Epoch 80/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9868 - loss: 0.0355 - val_accuracy: 0.9089 - val_loss: 0.3978
# Epoch 81/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9888 - loss: 0.0318 - val_accuracy: 0.8222 - val_loss: 2.4263
# Epoch 82/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9877 - loss: 0.0470 - val_accuracy: 0.8489 - val_loss: 1.0222
# Epoch 83/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9893 - loss: 0.0350 - val_accuracy: 0.7378 - val_loss: 6.1283
# Epoch 84/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9849 - loss: 0.0468 - val_accuracy: 0.9244 - val_loss: 0.7444
# Epoch 85/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9949 - loss: 0.0171 - val_accuracy: 0.8711 - val_loss: 0.9498
# Epoch 86/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9899 - loss: 0.0301 - val_accuracy: 0.7689 - val_loss: 2.3366
# Epoch 87/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9906 - loss: 0.0475 - val_accuracy: 0.9156 - val_loss: 0.3573
# Epoch 88/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9880 - loss: 0.0444 - val_accuracy: 0.9000 - val_loss: 0.4032
# Epoch 89/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9885 - loss: 0.0378 - val_accuracy: 0.8733 - val_loss: 0.6158
# Epoch 90/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9881 - loss: 0.0322 - val_accuracy: 0.9378 - val_loss: 0.2910
# Epoch 91/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9852 - loss: 0.0359 - val_accuracy: 0.7800 - val_loss: 1.0159
# Epoch 92/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9817 - loss: 0.0573 - val_accuracy: 0.9222 - val_loss: 0.4523
# Epoch 93/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9870 - loss: 0.0484 - val_accuracy: 0.9000 - val_loss: 0.3937
# Epoch 94/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9875 - loss: 0.0335 - val_accuracy: 0.7978 - val_loss: 1.3292
# Epoch 95/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9909 - loss: 0.0352 - val_accuracy: 0.9622 - val_loss: 0.2074
# Epoch 96/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9892 - loss: 0.0412 - val_accuracy: 0.8089 - val_loss: 2.3745
# Epoch 97/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9882 - loss: 0.0418 - val_accuracy: 0.7667 - val_loss: 2.0515
# Epoch 98/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9903 - loss: 0.0294 - val_accuracy: 0.9511 - val_loss: 0.2195
# Epoch 99/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9919 - loss: 0.0220 - val_accuracy: 0.8844 - val_loss: 0.5212
# Epoch 100/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9923 - loss: 0.0203 - val_accuracy: 0.9444 - val_loss: 0.2696

# %%
metrics = history.history
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
test_audio = []
test_labels = []

for audio, label in test_ds:
  test_audio.append(audio.numpy())
  test_labels.append(label.numpy())

test_audio = np.array(test_audio)
test_labels = np.array(test_labels)

# %%
y_pred = np.argmax(model.predict(test_audio), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Test set accuracy: {test_acc:.0%}')
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Test set accuracy: 94%

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))  # Adjust figure size as necessary
sns.heatmap(confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g',
            cmap='coolwarm')
plt.xlabel('Predykcja')
plt.ylabel('Etykieta')
plt.tight_layout()  # Automatically adjust layout to reduce white space
plt.savefig('Images/confusion_matrix.png', bbox_inches='tight')  # Save with reduced white space
plt.show()

# %%
#model.save('model_wszystko.h5')

# %%
# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# tflite_model = converter.convert()

# with open('model_wszystko.tflite', 'wb') as f:
#   f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\kstal\AppData\Local\Temp\tmpnqluaukf\assets
# INFO:tensorflow:Assets written to: C:\Users\kstal\AppData\Local\Temp\tmpnqluaukf\assets
# Saved artifact at 'C:\Users\kstal\AppData\Local\Temp\tmpnqluaukf'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 124, 129, 1), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 9), dtype=tf.float32, name=None)
# Captures:
#   1333859166416: TensorSpec(shape=(1, 1, 1), dtype=tf.float32, name=None)
#   1333746263216: TensorSpec(shape=(1, 1, 1), dtype=tf.float32, name=None)
#   1333784587680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333784590672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333784583104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333784581872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333784591552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333784588384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333784798208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333784801552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333784802960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333784800672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333784796976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333784804720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333784589264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333785105984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333785104752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333785106512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333785102464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333785100704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333785107216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333785109328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333785105456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333785110912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333785101936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333785103344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333785105808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333785113024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333785116016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1333784898448: TensorSpec(shape=(), dtype=tf.resource, name=None)
